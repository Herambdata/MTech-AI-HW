# %% [markdown]
# # Assignment of AI by Heramb Mishra (D010)

# %% [markdown]
# # Difference Between Tensors and Multi-Dimensional Array

# %% [markdown]
# # Tensors

# %% [markdown]
# Tensors are different type of object from a multidimensional array. Tensors are a type of a function.
# If we define a tensor, we have to specify the transformation rules for the tensor.

# %% [markdown]
# # Multi-Dimensional Array

# %% [markdown]
# 1. Multidimensional Array are a different type of object that tensors. Multidimensional arrays are the data structures suitable for representing a tensor in a coordinate plane.
# 2. Multidimensional arrays usually can be thought of a collection of numbers with no specific transformations needed to described alongside.

# %% [markdown]
# # Binary Search Tree Implementation with Insert and Traversal Feature

# %%
class Node(object):
    def __init__(self, data):
        self.data = data
        self.leftChild = None
        self.rightChild = None

    def insert(self, data):
        if self.data == data:
            return False        

        elif data < self.data:
            if self.leftChild:
                return self.leftChild.insert(data)
            else:
                self.leftChild = Node(data)
                return True

        else:
            if self.rightChild:
                return self.rightChild.insert(data)
            else:
                self.rightChild = Node(data)
                return True

    def minValueNode(self, node):
        current = node
        
        while(current.leftChild is not None):
            current = current.leftChild

        return current

    def preorder(self):
        # preorder traversal
        if self:
            print(str(self.data), end = ' ')
            if self.leftChild:
                self.leftChild.preorder()
            if self.rightChild:
                self.rightChild.preorder()

    def inorder(self):
        # Inorder traversal
        if self:
            if self.leftChild:
                self.leftChild.inorder()
            print(str(self.data), end = ' ')
            if self.rightChild:
                self.rightChild.inorder()

    def postorder(self):
        # postorder traversal
        if self:
            if self.leftChild:
                self.leftChild.postorder()
            if self.rightChild:
                self.rightChild.postorder()
            print(str(self.data), end = ' ')

# %% [markdown]
# ## Tree Traversal Options
# ### 1. Preorder
# ### 2. Postorder
# ### 3. Inorder

# %%
class Tree(object):
    def __init__(self):
        self.root = None

    def insert(self, data):
        if self.root:
            return self.root.insert(data)
        else:
            self.root = Node(data)
            return True

    def preorder(self):
        if self.root is not None:
            print()
            print('Preorder: ')
            self.root.preorder()

    def inorder(self):
        print()
        if self.root is not None:
            print('Inorder: ')
            self.root.inorder()

    def postorder(self):
        print()
        if self.root is not None:
            print('Postorder: ')
            self.root.postorder()

# %%
if __name__ == '__main__':
    tree = Tree()
    tree.insert(10)
    tree.insert(12)
    tree.insert(5)
    tree.insert(4)
    tree.insert(20)
    tree.insert(8)
    tree.insert(7)
    tree.insert(15)
    tree.insert(13)
    tree.insert(14)
    tree.insert(16)
    tree.insert(1)
    tree.insert(6)
    tree.insert(45)
    tree.insert(32)
    tree.insert(3)
    tree.preorder()
    tree.inorder()
    tree.postorder()
# Out:
# Preorder:
# 10 5 4 1 3 8 7 6 12 20 15 13 14 16 45 32
# Inorder:
# 1 3 4 5 6 7 8 10 12 13 14 15 16 20 32 45
# Postorder:
# 3 1 4 6 7 8 5 14 13 16 15 32 45 20 12 10

# %%
from binarytree import bst

# %%
myt = bst(height=9,is_perfect=True)

# %%
print(myt)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  _____________________________________________________________________________________
# ...

# %% [markdown]
# # Building Graph Using Networkx library and as well as custom graph code and Depth First Search is implemented

# %%
#!pip install networkx
import networkx as nx

# %%
h=nx.complete_graph(10)

# %%
nx.draw(h)

# %%
print(h.number_of_edges())
print(h.number_of_nodes())
# Out:
# 45
# 10

# %%
class Graph():
    def __init__(self):
        self.vertex = {}

    # for printing the Graph vertexes
    def printGraph(self):
        print(self.vertex)
        for i in self.vertex.keys():
            print(i,' -> ', ' -> '.join([str(j) for j in self.vertex[i]]))

    def addEdge(self, fromEdge, toEdge):
        if fromEdge in self.vertex.keys():
            self.vertex[fromEdge].append(toEdge)
        else:
            self.vertex[fromEdge] = [toEdge]

    def DFS(self):
        visited = [False] * len(self.vertex)
        for i in range(len(self.vertex)):
            if visited[i] == False:
                self.DFSRec(i, visited)

    def DFSRec(self, startVertex, visited):
        visited[startVertex] = True
        print(startVertex, end = ' ')
        for i in self.vertex.keys():
            if visited[i] == False:
                self.DFSRec(i, visited)

if __name__ == '__main__':
    g = Graph()
    g.addEdge(0, 1)
    g.addEdge(0, 2)
    g.addEdge(1, 2)
    g.addEdge(2, 0)
    g.addEdge(2, 3)
    g.addEdge(3, 3)
    g.addEdge(4, 5)
    g.addEdge(4, 2)
    g.addEdge(5, 1)

    g.printGraph()
    print('DFS:')
    g.DFS()
# Out:
# {0: [1, 2], 1: [2], 2: [0, 3], 3: [3], 4: [5, 2], 5: [1]}
# 0  ->  1 -> 2
# 1  ->  2
# 2  ->  0 -> 3
# 3  ->  3
# 4  ->  5 -> 2
# 5  ->  1
# DFS:
# 0 1 2 3 4 5
