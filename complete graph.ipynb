# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
h=nx.complete_graph(10)

# %%
nx.draw(h)

# %%
h.number_of_edges()
# Out:
# 45

# %%
h.number_of_nodes()
# Out:
# 10

# %%
d = nx.binomial_tree(5)

# %%
nx.draw(d)

# %%
d.size()
# Out:
# 31
